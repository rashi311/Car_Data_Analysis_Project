# %%
#Start by importing all important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the csv file and assign it to a variable .
df=pd.read_csv('Cars.csv')
print(df.head(5))
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#Display shape of dataframe
print(df.shape)
# Out:
# (398, 9)

# %%
#Print all columns of dataframe.Return an array containing names of all the columns.
column_names=df.columns
print(column_names)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
#Set the 'name' column as the index of dataframe
df=df.set_index('name')

# %%
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
#Print a list of all the unique mpg values
unique_values=df['mpg'].unique().tolist()
print(unique_values)
# Out:
# [18.0, 15.0, 16.0, 17.0, 14.0, 24.0, 22.0, 21.0, 27.0, 26.0, 25.0, 10.0, 11.0, 9.0, 28.0, 19.0, 12.0, 13.0, 23.0, 30.0, 31.0, 35.0, 20.0, 29.0, 32.0, 33.0, 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5, 26.5, 16.5, 31.5, 36.0, 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1, 32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1, 17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2, 19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2, 34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4, 24.3, 19.1, 34.3, 29.8, 31.3, 37.0, 32.2, 46.6, 27.9, 40.8, 44.3, 43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8, 23.5, 39.1, 39.0, 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9, 31.6, 28.1, 30.7, 24.2, 22.4, 34.0, 38.0, 44.0]

# %%
#Create a column which contains the horsepower divided by weightas its metric and make this new column the index.
df['hp_per_weight']=df['horsepower']/df['weight']
df.set_index('hp_per_weight')
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.037100       18.0          8         307.0       130.0    3504
# 0.044679       15.0          8         350.0       165.0    3693
# 0.043655       18.0          8         318.0       150.0    3436
# 0.043694       16.0          8         304.0       150.0    3433
# 0.040591       17.0          8         302.0       140.0    3449
# ...             ...        ...           ...         ...     ...
# 0.030824       27.0          4         140.0        86.0    2790
# 0.024413       44.0          4          97.0        52.0    2130
# 0.036601       32.0          4         135.0        84.0    2295
# 0.030095       28.0          4         120.0        79.0    2625
# 0.030147       31.0          4         119.0        82.0    2720
#
#                acceleration  model_year  origin
# hp_per_weight
# 0.037100               12.0          70     usa
# 0.044679               11.5          70     usa
# ...

# %%
df = df.reset_index() 
df = df.set_index('name')

# %%
df
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
#What is name of car that has the highest horsepower?
highest_car_hp=df['horsepower'].max()
print(highest_car_hp)
# Out:
# 230.0

# %%
#How many cars have mpg ≥ 35?
count = (df['mpg'] >= 35).sum()
print(count)
# Out:
# 36

# %%
#What is the most common origin for cars with horsepower > 100 and weight < 3000?
filtered_cars = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
most_common_origin = filtered_cars['origin'].mode()
print(most_common_origin)
# Out:
# 0    usa
# Name: origin, dtype: object

# %%
#What is the mean acceleration of cars from Japan? (rounded to 2 decimals)
mean_acceleration=df['acceleration'].mean()
print(round(mean_acceleration))
# Out:
# 16

# %%
#Which year had the highest average mpg?
mpg_each_year=df.groupby('model_year')['mpg']
avg_mpg_each_year=mpg_each_year.mean()

highest_avg_mpg_year=avg_mpg_each_year.idxmax()
print(highest_avg_mpg_year)
# Out:
# 80

# %%
#Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

median_mpg=df['mpg'].median()
car_df = df[df['mpg']>median_mpg]
max_ratio=car_df['hp_per_weight'].max()
best_cars = car_df[car_df['hp_per_weight'] == max_ratio]
print(best_cars)
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# name
# bmw 2002  26.0          4         121.0       113.0    2234          12.5
#
#           model_year  origin  hp_per_weight
# name
# bmw 2002          70  europe       0.050582

# %%
#Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
pivot_table = avg_mpg.pivot(index='model_year', columns='origin', values='mpg')
pivot_table.plot(marker='o', figsize=(10, 6))
plt.title('Average MPG Over Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df, x='model_year', y='mpg', hue='origin', estimator='mean', marker='o')

# Customize
plt.title('Average MPG Over Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
'''Create a Seaborn scatterplot (or PairGrid) where:
X = horsepower

Y = weight

Color by: origin

Size by: mpg

Hue order = ['japan', 'europe', 'usa']

Add meaningful plot titles and axis titles.
'''
sns.scatterplot(data=df,x="horsepower",y='weight',hue='origin',size='mpg',hue_order=['japan','europe','usa'])
plt.title('Horsepower vs Weight of Cars by Origin and MPG Size', fontsize=14)
plt.xlabel('horsepower')
plt.ylabel('weight')
plt.show()

# %%
#Identify car names that appear in more than one model_year.
carnames_year_count=df.groupby('name')['model_year'].nunique()
duplicate_names = carnames_year_count[carnames_year_count > 1].index.tolist()
for name in duplicate_names:
    print(name)
# Out:
# amc concord
# amc gremlin
# amc hornet
# amc matador
# amc matador (sw)
# audi 100ls
# buick century
# buick estate wagon (sw)
# buick skylark
# chevrolet caprice classic
# chevrolet chevelle malibu
# chevrolet chevelle malibu classic
# chevrolet chevette
# chevrolet citation
# chevrolet impala
# chevrolet malibu
# chevrolet monte carlo landau
# chevrolet nova
# chevrolet vega
# datsun 210
# datsun 710
# datsun pl510
# dodge aspen
# dodge colt
# fiat 128
# ford country squire (sw)
# ford galaxie 500
# ford gran torino
# ford gran torino (sw)
# ford ltd
# ford maverick
# ford pinto
# honda accord
# honda civic
# honda civic cvcc
# mazda 626
# oldsmobile cutlass salon brougham
# opel 1900
# opel manta
# peugeot 504
# plymouth duster
# plymouth fury iii
# plymouth valiant
# pontiac catalina
# pontiac phoenix
# saab 99le
# subaru
# subaru dl
# toyota corolla
# toyota corolla 1200
# toyota corona
# toyota mark ii
# volkswagen dasher
# volkswagen rabbit
# vw rabbit

# %%
#For each such name, compute the standard deviation of mpg across years.
df=df.reset_index()

carnames_year_count=df.groupby('name')['model_year'].nunique()
duplicate_names = carnames_year_count[carnames_year_count > 1].index
duplicate_cars_df = df[df['name'].isin(duplicate_names)]
mpg_std_by_name = duplicate_cars_df.groupby('name')['mpg'].std()
print(mpg_std_by_name.sort_values(ascending=False))
# Out:
# name
# vw rabbit                            8.838835
# honda civic                          7.094599
# datsun 210                           6.363961
# datsun 710                           5.656854
# chevrolet malibu                     5.303301
# pontiac phoenix                      4.596194
# subaru                               4.454773
# buick skylark                        4.313351
# buick century                        3.818377
# ford pinto                           3.638910
# fiat 128                             3.535534
# chevrolet nova                       3.511885
# peugeot 504                          3.484729
# amc concord                          3.464823
# ford maverick                        3.420526
# toyota corona                        3.119161
# volkswagen dasher                    2.929733
# chevrolet citation                   2.857155
# plymouth valiant                     2.828427
# oldsmobile cutlass salon brougham    2.828427
# ...

# %%
#Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0
name_year_counts = df.groupby('name')['model_year'].nunique()
duplicate_names = name_year_counts[name_year_counts >= 2].index
duplicate_cars_df = df[df['name'].isin(duplicate_names)]
mpg_std_by_name = duplicate_cars_df.groupby('name')['mpg'].std()
low_variation_cars = mpg_std_by_name[mpg_std_by_name < 1.0]
min_std = low_variation_cars.min()
cars_with_lowest_variation = low_variation_cars[low_variation_cars == min_std].index.tolist()


for car in cars_with_lowest_variation:
    print(car)
# Out:
# datsun pl510

# %%
#Report the model name(s), number of appearances, and the average mpg.
name_year_counts = df.groupby('name')['model_year'].nunique()
duplicate_names = name_year_counts[name_year_counts >= 2].index
duplicate_cars_df = df[df['name'].isin(duplicate_names)]
mpg_std_by_name = duplicate_cars_df.groupby('name')['mpg'].std()
low_variation_cars = mpg_std_by_name[mpg_std_by_name < 1.0]
min_std = low_variation_cars.min()
cars_with_lowest_variation = low_variation_cars[low_variation_cars == min_std].index.tolist()

result = duplicate_cars_df[duplicate_cars_df['name'].isin(cars_with_lowest_variation)].groupby('name').agg(
    appearances=('model_year', 'count'),
    average_mpg=('mpg', 'mean')
).reset_index()

print(result)
# Out:
#            name  appearances  average_mpg
# 0  datsun pl510            2         27.0

# %%
df
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin  hp_per_weight
# ...
